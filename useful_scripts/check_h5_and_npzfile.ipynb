# %%
# check what is in one h5 file
import h5py
import os

def parse_h5_file(file_path):
    # 检查文件是否存在
    if not os.path.exists(file_path):
        print(f"错误：文件 '{file_path}' 不存在。")
        return

    try:
        with h5py.File(file_path, 'r') as f:
            print(f"\n正在解析 H5 文件: {file_path}")
            print("="*60)

            # 递归遍历文件结构
            def print_structure(group, prefix=""):
                for key in group.keys():
                    item = group[key]
                    if isinstance(item, h5py.Dataset):
                        print(f"{prefix}数据集: {key} -> 形状: {item.shape}, 类型: {item.dtype}")
                    elif isinstance(item, h5py.Group):
                        print(f"{prefix}组: {key}")
                    # 打印属性（如果有）
                    if item.attrs:
                        for attr_name, attr_value in item.attrs.items():
                            print(f"{prefix}  属性: {key}.{attr_name} = {attr_value}")
                    # 递归进入子组
                    if isinstance(item, h5py.Group):
                        print_structure(item, prefix + "  ")

            # 开始打印结构
            print_structure(f)

    except Exception as e:
        print(f"读取文件时发生错误: {e}")

# 主程序
if __name__ == "__main__":
    path = "/home/wdy02/wdy_program/simulation_plus/IsaacLab/induman_data/00_all_h5files/ASSEMBLE_2PIN_PLUG_SOCKET_final.h5"
    parse_h5_file(path)
# Out:
# 正在解析 H5 文件: /home/wdy02/wdy_program/simulation_plus/IsaacLab/induman_data/00_all_h5files/ASSEMBLE_2PIN_PLUG_SOCKET_final.h5
# ============================================================
# 组: data_frames
#   属性: data_frames.env_name = FrankaGym
#   属性: data_frames.task_name = ASSEMBLE_2PIN_PLUG_SOCKET
#   组: demo_0
#     属性: demo_0.demo_name = 1755848831.4360902_episode_374.json
#     数据集: actions -> 形状: (375, 7), 类型: float64
#     数据集: episode_step -> 形状: (375,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (375, 2), 类型: float32
#     数据集: is_success -> 形状: (375,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (375, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (375, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (375, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (375, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (375, 3), 类型: float32
#     数据集: rewards -> 形状: (375,), 类型: float64
#     数据集: robot_joint_states -> 形状: (375, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (375, 54), 类型: float32
#     数据集: socket_poses -> 形状: (375, 7), 类型: float32
#   组: demo_1
#     属性: demo_1.demo_name = 1755848935.4734142_episode_298.json
#     数据集: actions -> 形状: (299, 7), 类型: float64
#     数据集: episode_step -> 形状: (299,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (299, 2), 类型: float32
#     数据集: is_success -> 形状: (299,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (299, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (299, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (299, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (299, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (299, 3), 类型: float32
#     数据集: rewards -> 形状: (299,), 类型: float64
#     数据集: robot_joint_states -> 形状: (299, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (299, 54), 类型: float32
#     数据集: socket_poses -> 形状: (299, 7), 类型: float32
#   组: demo_10
#     属性: demo_10.demo_name = 1755849435.5982096_episode_266.json
#     数据集: actions -> 形状: (267, 7), 类型: float64
#     数据集: episode_step -> 形状: (267,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (267, 2), 类型: float32
#     数据集: is_success -> 形状: (267,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (267, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (267, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (267, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (267, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (267, 3), 类型: float32
#     数据集: rewards -> 形状: (267,), 类型: float64
#     数据集: robot_joint_states -> 形状: (267, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (267, 54), 类型: float32
#     数据集: socket_poses -> 形状: (267, 7), 类型: float32
#   组: demo_11
#     属性: demo_11.demo_name = 1755849482.3980968_episode_351.json
#     数据集: actions -> 形状: (352, 7), 类型: float64
#     数据集: episode_step -> 形状: (352,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (352, 2), 类型: float32
#     数据集: is_success -> 形状: (352,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (352, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (352, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (352, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (352, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (352, 3), 类型: float32
#     数据集: rewards -> 形状: (352,), 类型: float64
#     数据集: robot_joint_states -> 形状: (352, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (352, 54), 类型: float32
#     数据集: socket_poses -> 形状: (352, 7), 类型: float32
#   组: demo_12
#     属性: demo_12.demo_name = 1755849556.9632137_episode_191.json
#     数据集: actions -> 形状: (192, 7), 类型: float64
#     数据集: episode_step -> 形状: (192,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (192, 2), 类型: float32
#     数据集: is_success -> 形状: (192,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (192, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (192, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (192, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (192, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (192, 3), 类型: float32
#     数据集: rewards -> 形状: (192,), 类型: float64
#     数据集: robot_joint_states -> 形状: (192, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (192, 54), 类型: float32
#     数据集: socket_poses -> 形状: (192, 7), 类型: float32
#   组: demo_13
#     属性: demo_13.demo_name = 1755849647.6903822_episode_290.json
#     数据集: actions -> 形状: (291, 7), 类型: float64
#     数据集: episode_step -> 形状: (291,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (291, 2), 类型: float32
#     数据集: is_success -> 形状: (291,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (291, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (291, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (291, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (291, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (291, 3), 类型: float32
#     数据集: rewards -> 形状: (291,), 类型: float64
#     数据集: robot_joint_states -> 形状: (291, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (291, 54), 类型: float32
#     数据集: socket_poses -> 形状: (291, 7), 类型: float32
#   组: demo_14
#     属性: demo_14.demo_name = 1755849695.6261992_episode_315.json
#     数据集: actions -> 形状: (316, 7), 类型: float64
#     数据集: episode_step -> 形状: (316,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (316, 2), 类型: float32
#     数据集: is_success -> 形状: (316,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (316, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (316, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (316, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (316, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (316, 3), 类型: float32
#     数据集: rewards -> 形状: (316,), 类型: float64
#     数据集: robot_joint_states -> 形状: (316, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (316, 54), 类型: float32
#     数据集: socket_poses -> 形状: (316, 7), 类型: float32
#   组: demo_15
#     属性: demo_15.demo_name = 1755849737.9484174_episode_311.json
#     数据集: actions -> 形状: (312, 7), 类型: float64
#     数据集: episode_step -> 形状: (312,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (312, 2), 类型: float32
#     数据集: is_success -> 形状: (312,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (312, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (312, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (312, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (312, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (312, 3), 类型: float32
#     数据集: rewards -> 形状: (312,), 类型: float64
#     数据集: robot_joint_states -> 形状: (312, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (312, 54), 类型: float32
#     数据集: socket_poses -> 形状: (312, 7), 类型: float32
#   组: demo_16
#     属性: demo_16.demo_name = 1755849813.1509063_episode_291.json
#     数据集: actions -> 形状: (292, 7), 类型: float64
#     数据集: episode_step -> 形状: (292,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (292, 2), 类型: float32
#     数据集: is_success -> 形状: (292,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (292, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (292, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (292, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (292, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (292, 3), 类型: float32
#     数据集: rewards -> 形状: (292,), 类型: float64
#     数据集: robot_joint_states -> 形状: (292, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (292, 54), 类型: float32
#     数据集: socket_poses -> 形状: (292, 7), 类型: float32
#   组: demo_17
#     属性: demo_17.demo_name = 1755849895.5645568_episode_273.json
#     数据集: actions -> 形状: (274, 7), 类型: float64
#     数据集: episode_step -> 形状: (274,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (274, 2), 类型: float32
#     数据集: is_success -> 形状: (274,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (274, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (274, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (274, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (274, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (274, 3), 类型: float32
#     数据集: rewards -> 形状: (274,), 类型: float64
#     数据集: robot_joint_states -> 形状: (274, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (274, 54), 类型: float32
#     数据集: socket_poses -> 形状: (274, 7), 类型: float32
#   组: demo_18
#     属性: demo_18.demo_name = 1755849948.0799253_episode_222.json
#     数据集: actions -> 形状: (223, 7), 类型: float64
#     数据集: episode_step -> 形状: (223,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (223, 2), 类型: float32
#     数据集: is_success -> 形状: (223,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (223, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (223, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (223, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (223, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (223, 3), 类型: float32
#     数据集: rewards -> 形状: (223,), 类型: float64
#     数据集: robot_joint_states -> 形状: (223, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (223, 54), 类型: float32
#     数据集: socket_poses -> 形状: (223, 7), 类型: float32
#   组: demo_19
#     属性: demo_19.demo_name = 1755849976.2036304_episode_186.json
#     数据集: actions -> 形状: (187, 7), 类型: float64
#     数据集: episode_step -> 形状: (187,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (187, 2), 类型: float32
#     数据集: is_success -> 形状: (187,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (187, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (187, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (187, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (187, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (187, 3), 类型: float32
#     数据集: rewards -> 形状: (187,), 类型: float64
#     数据集: robot_joint_states -> 形状: (187, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (187, 54), 类型: float32
#     数据集: socket_poses -> 形状: (187, 7), 类型: float32
#   组: demo_2
#     属性: demo_2.demo_name = 1755848972.7490172_episode_255.json
#     数据集: actions -> 形状: (256, 7), 类型: float64
#     数据集: episode_step -> 形状: (256,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (256, 2), 类型: float32
#     数据集: is_success -> 形状: (256,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (256, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (256, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (256, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (256, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (256, 3), 类型: float32
#     数据集: rewards -> 形状: (256,), 类型: float64
#     数据集: robot_joint_states -> 形状: (256, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (256, 54), 类型: float32
#     数据集: socket_poses -> 形状: (256, 7), 类型: float32
#   组: demo_20
#     属性: demo_20.demo_name = 1755850018.1347268_episode_270.json
#     数据集: actions -> 形状: (271, 7), 类型: float64
#     数据集: episode_step -> 形状: (271,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (271, 2), 类型: float32
#     数据集: is_success -> 形状: (271,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (271, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (271, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (271, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (271, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (271, 3), 类型: float32
#     数据集: rewards -> 形状: (271,), 类型: float64
#     数据集: robot_joint_states -> 形状: (271, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (271, 54), 类型: float32
#     数据集: socket_poses -> 形状: (271, 7), 类型: float32
#   组: demo_21
#     属性: demo_21.demo_name = 1755850054.8740425_episode_253.json
#     数据集: actions -> 形状: (254, 7), 类型: float64
#     数据集: episode_step -> 形状: (254,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (254, 2), 类型: float32
#     数据集: is_success -> 形状: (254,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (254, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (254, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (254, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (254, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (254, 3), 类型: float32
#     数据集: rewards -> 形状: (254,), 类型: float64
#     数据集: robot_joint_states -> 形状: (254, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (254, 54), 类型: float32
#     数据集: socket_poses -> 形状: (254, 7), 类型: float32
#   组: demo_22
#     属性: demo_22.demo_name = 1755850094.8858747_episode_307.json
#     数据集: actions -> 形状: (308, 7), 类型: float64
#     数据集: episode_step -> 形状: (308,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (308, 2), 类型: float32
#     数据集: is_success -> 形状: (308,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (308, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (308, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (308, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (308, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (308, 3), 类型: float32
#     数据集: rewards -> 形状: (308,), 类型: float64
#     数据集: robot_joint_states -> 形状: (308, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (308, 54), 类型: float32
#     数据集: socket_poses -> 形状: (308, 7), 类型: float32
#   组: demo_23
#     属性: demo_23.demo_name = 1755850133.193341_episode_252.json
#     数据集: actions -> 形状: (253, 7), 类型: float64
#     数据集: episode_step -> 形状: (253,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (253, 2), 类型: float32
#     数据集: is_success -> 形状: (253,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (253, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (253, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (253, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (253, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (253, 3), 类型: float32
#     数据集: rewards -> 形状: (253,), 类型: float64
#     数据集: robot_joint_states -> 形状: (253, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (253, 54), 类型: float32
#     数据集: socket_poses -> 形状: (253, 7), 类型: float32
#   组: demo_24
#     属性: demo_24.demo_name = 1755850167.8201256_episode_226.json
#     数据集: actions -> 形状: (227, 7), 类型: float64
#     数据集: episode_step -> 形状: (227,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (227, 2), 类型: float32
#     数据集: is_success -> 形状: (227,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (227, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (227, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (227, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (227, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (227, 3), 类型: float32
#     数据集: rewards -> 形状: (227,), 类型: float64
#     数据集: robot_joint_states -> 形状: (227, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (227, 54), 类型: float32
#     数据集: socket_poses -> 形状: (227, 7), 类型: float32
#   组: demo_25
#     属性: demo_25.demo_name = 1755850209.447291_episode_309.json
#     数据集: actions -> 形状: (310, 7), 类型: float64
#     数据集: episode_step -> 形状: (310,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (310, 2), 类型: float32
#     数据集: is_success -> 形状: (310,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (310, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (310, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (310, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (310, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (310, 3), 类型: float32
#     数据集: rewards -> 形状: (310,), 类型: float64
#     数据集: robot_joint_states -> 形状: (310, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (310, 54), 类型: float32
#     数据集: socket_poses -> 形状: (310, 7), 类型: float32
#   组: demo_26
#     属性: demo_26.demo_name = 1755850278.187009_episode_276.json
#     数据集: actions -> 形状: (277, 7), 类型: float64
#     数据集: episode_step -> 形状: (277,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (277, 2), 类型: float32
#     数据集: is_success -> 形状: (277,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (277, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (277, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (277, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (277, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (277, 3), 类型: float32
#     数据集: rewards -> 形状: (277,), 类型: float64
#     数据集: robot_joint_states -> 形状: (277, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (277, 54), 类型: float32
#     数据集: socket_poses -> 形状: (277, 7), 类型: float32
#   组: demo_27
#     属性: demo_27.demo_name = 1755850318.0285819_episode_284.json
#     数据集: actions -> 形状: (285, 7), 类型: float64
#     数据集: episode_step -> 形状: (285,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (285, 2), 类型: float32
#     数据集: is_success -> 形状: (285,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (285, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (285, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (285, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (285, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (285, 3), 类型: float32
#     数据集: rewards -> 形状: (285,), 类型: float64
#     数据集: robot_joint_states -> 形状: (285, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (285, 54), 类型: float32
#     数据集: socket_poses -> 形状: (285, 7), 类型: float32
#   组: demo_28
#     属性: demo_28.demo_name = 1755850394.2890983_episode_203.json
#     数据集: actions -> 形状: (204, 7), 类型: float64
#     数据集: episode_step -> 形状: (204,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (204, 2), 类型: float32
#     数据集: is_success -> 形状: (204,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (204, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (204, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (204, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (204, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (204, 3), 类型: float32
#     数据集: rewards -> 形状: (204,), 类型: float64
#     数据集: robot_joint_states -> 形状: (204, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (204, 54), 类型: float32
#     数据集: socket_poses -> 形状: (204, 7), 类型: float32
#   组: demo_29
#     属性: demo_29.demo_name = 1755850434.4263465_episode_266.json
#     数据集: actions -> 形状: (267, 7), 类型: float64
#     数据集: episode_step -> 形状: (267,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (267, 2), 类型: float32
#     数据集: is_success -> 形状: (267,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (267, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (267, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (267, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (267, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (267, 3), 类型: float32
#     数据集: rewards -> 形状: (267,), 类型: float64
#     数据集: robot_joint_states -> 形状: (267, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (267, 54), 类型: float32
#     数据集: socket_poses -> 形状: (267, 7), 类型: float32
#   组: demo_3
#     属性: demo_3.demo_name = 1755849003.8414254_episode_207.json
#     数据集: actions -> 形状: (208, 7), 类型: float64
#     数据集: episode_step -> 形状: (208,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (208, 2), 类型: float32
#     数据集: is_success -> 形状: (208,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (208, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (208, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (208, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (208, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (208, 3), 类型: float32
#     数据集: rewards -> 形状: (208,), 类型: float64
#     数据集: robot_joint_states -> 形状: (208, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (208, 54), 类型: float32
#     数据集: socket_poses -> 形状: (208, 7), 类型: float32
#   组: demo_30
#     属性: demo_30.demo_name = 1755850504.9946373_episode_245.json
#     数据集: actions -> 形状: (246, 7), 类型: float64
#     数据集: episode_step -> 形状: (246,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (246, 2), 类型: float32
#     数据集: is_success -> 形状: (246,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (246, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (246, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (246, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (246, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (246, 3), 类型: float32
#     数据集: rewards -> 形状: (246,), 类型: float64
#     数据集: robot_joint_states -> 形状: (246, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (246, 54), 类型: float32
#     数据集: socket_poses -> 形状: (246, 7), 类型: float32
#   组: demo_31
#     属性: demo_31.demo_name = 1755850538.023683_episode_234.json
#     数据集: actions -> 形状: (235, 7), 类型: float64
#     数据集: episode_step -> 形状: (235,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (235, 2), 类型: float32
#     数据集: is_success -> 形状: (235,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (235, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (235, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (235, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (235, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (235, 3), 类型: float32
#     数据集: rewards -> 形状: (235,), 类型: float64
#     数据集: robot_joint_states -> 形状: (235, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (235, 54), 类型: float32
#     数据集: socket_poses -> 形状: (235, 7), 类型: float32
#   组: demo_32
#     属性: demo_32.demo_name = 1755850702.15996_episode_305.json
#     数据集: actions -> 形状: (306, 7), 类型: float64
#     数据集: episode_step -> 形状: (306,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (306, 2), 类型: float32
#     数据集: is_success -> 形状: (306,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (306, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (306, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (306, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (306, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (306, 3), 类型: float32
#     数据集: rewards -> 形状: (306,), 类型: float64
#     数据集: robot_joint_states -> 形状: (306, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (306, 54), 类型: float32
#     数据集: socket_poses -> 形状: (306, 7), 类型: float32
#   组: demo_33
#     属性: demo_33.demo_name = 1755850792.576992_episode_304.json
#     数据集: actions -> 形状: (305, 7), 类型: float64
#     数据集: episode_step -> 形状: (305,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (305, 2), 类型: float32
#     数据集: is_success -> 形状: (305,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (305, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (305, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (305, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (305, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (305, 3), 类型: float32
#     数据集: rewards -> 形状: (305,), 类型: float64
#     数据集: robot_joint_states -> 形状: (305, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (305, 54), 类型: float32
#     数据集: socket_poses -> 形状: (305, 7), 类型: float32
#   组: demo_34
#     属性: demo_34.demo_name = 1755850881.7751813_episode_257.json
#     数据集: actions -> 形状: (258, 7), 类型: float64
#     数据集: episode_step -> 形状: (258,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (258, 2), 类型: float32
#     数据集: is_success -> 形状: (258,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (258, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (258, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (258, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (258, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (258, 3), 类型: float32
#     数据集: rewards -> 形状: (258,), 类型: float64
#     数据集: robot_joint_states -> 形状: (258, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (258, 54), 类型: float32
#     数据集: socket_poses -> 形状: (258, 7), 类型: float32
#   组: demo_35
#     属性: demo_35.demo_name = 1755850921.095037_episode_264.json
#     数据集: actions -> 形状: (265, 7), 类型: float64
#     数据集: episode_step -> 形状: (265,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (265, 2), 类型: float32
#     数据集: is_success -> 形状: (265,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (265, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (265, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (265, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (265, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (265, 3), 类型: float32
#     数据集: rewards -> 形状: (265,), 类型: float64
#     数据集: robot_joint_states -> 形状: (265, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (265, 54), 类型: float32
#     数据集: socket_poses -> 形状: (265, 7), 类型: float32
#   组: demo_36
#     属性: demo_36.demo_name = 1755850954.9390197_episode_238.json
#     数据集: actions -> 形状: (239, 7), 类型: float64
#     数据集: episode_step -> 形状: (239,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (239, 2), 类型: float32
#     数据集: is_success -> 形状: (239,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (239, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (239, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (239, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (239, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (239, 3), 类型: float32
#     数据集: rewards -> 形状: (239,), 类型: float64
#     数据集: robot_joint_states -> 形状: (239, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (239, 54), 类型: float32
#     数据集: socket_poses -> 形状: (239, 7), 类型: float32
#   组: demo_37
#     属性: demo_37.demo_name = 1755850997.2668948_episode_314.json
#     数据集: actions -> 形状: (315, 7), 类型: float64
#     数据集: episode_step -> 形状: (315,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (315, 2), 类型: float32
#     数据集: is_success -> 形状: (315,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (315, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (315, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (315, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (315, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (315, 3), 类型: float32
#     数据集: rewards -> 形状: (315,), 类型: float64
#     数据集: robot_joint_states -> 形状: (315, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (315, 54), 类型: float32
#     数据集: socket_poses -> 形状: (315, 7), 类型: float32
#   组: demo_38
#     属性: demo_38.demo_name = 1755851043.3257256_episode_309.json
#     数据集: actions -> 形状: (310, 7), 类型: float64
#     数据集: episode_step -> 形状: (310,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (310, 2), 类型: float32
#     数据集: is_success -> 形状: (310,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (310, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (310, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (310, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (310, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (310, 3), 类型: float32
#     数据集: rewards -> 形状: (310,), 类型: float64
#     数据集: robot_joint_states -> 形状: (310, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (310, 54), 类型: float32
#     数据集: socket_poses -> 形状: (310, 7), 类型: float32
#   组: demo_39
#     属性: demo_39.demo_name = 1755851169.3986895_episode_241.json
#     数据集: actions -> 形状: (242, 7), 类型: float64
#     数据集: episode_step -> 形状: (242,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (242, 2), 类型: float32
#     数据集: is_success -> 形状: (242,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (242, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (242, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (242, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (242, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (242, 3), 类型: float32
#     数据集: rewards -> 形状: (242,), 类型: float64
#     数据集: robot_joint_states -> 形状: (242, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (242, 54), 类型: float32
#     数据集: socket_poses -> 形状: (242, 7), 类型: float32
#   组: demo_4
#     属性: demo_4.demo_name = 1755849171.6092107_episode_318.json
#     数据集: actions -> 形状: (319, 7), 类型: float64
#     数据集: episode_step -> 形状: (319,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (319, 2), 类型: float32
#     数据集: is_success -> 形状: (319,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (319, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (319, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (319, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (319, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (319, 3), 类型: float32
#     数据集: rewards -> 形状: (319,), 类型: float64
#     数据集: robot_joint_states -> 形状: (319, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (319, 54), 类型: float32
#     数据集: socket_poses -> 形状: (319, 7), 类型: float32
#   组: demo_40
#     属性: demo_40.demo_name = 1755851289.3316536_episode_218.json
#     数据集: actions -> 形状: (219, 7), 类型: float64
#     数据集: episode_step -> 形状: (219,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (219, 2), 类型: float32
#     数据集: is_success -> 形状: (219,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (219, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (219, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (219, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (219, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (219, 3), 类型: float32
#     数据集: rewards -> 形状: (219,), 类型: float64
#     数据集: robot_joint_states -> 形状: (219, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (219, 54), 类型: float32
#     数据集: socket_poses -> 形状: (219, 7), 类型: float32
#   组: demo_41
#     属性: demo_41.demo_name = 1755851327.201262_episode_237.json
#     数据集: actions -> 形状: (238, 7), 类型: float64
#     数据集: episode_step -> 形状: (238,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (238, 2), 类型: float32
#     数据集: is_success -> 形状: (238,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (238, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (238, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (238, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (238, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (238, 3), 类型: float32
#     数据集: rewards -> 形状: (238,), 类型: float64
#     数据集: robot_joint_states -> 形状: (238, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (238, 54), 类型: float32
#     数据集: socket_poses -> 形状: (238, 7), 类型: float32
#   组: demo_42
#     属性: demo_42.demo_name = 1755851483.3366036_episode_348.json
#     数据集: actions -> 形状: (349, 7), 类型: float64
#     数据集: episode_step -> 形状: (349,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (349, 2), 类型: float32
#     数据集: is_success -> 形状: (349,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (349, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (349, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (349, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (349, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (349, 3), 类型: float32
#     数据集: rewards -> 形状: (349,), 类型: float64
#     数据集: robot_joint_states -> 形状: (349, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (349, 54), 类型: float32
#     数据集: socket_poses -> 形状: (349, 7), 类型: float32
#   组: demo_43
#     属性: demo_43.demo_name = 1755851582.16998_episode_291.json
#     数据集: actions -> 形状: (292, 7), 类型: float64
#     数据集: episode_step -> 形状: (292,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (292, 2), 类型: float32
#     数据集: is_success -> 形状: (292,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (292, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (292, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (292, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (292, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (292, 3), 类型: float32
#     数据集: rewards -> 形状: (292,), 类型: float64
#     数据集: robot_joint_states -> 形状: (292, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (292, 54), 类型: float32
#     数据集: socket_poses -> 形状: (292, 7), 类型: float32
#   组: demo_44
#     属性: demo_44.demo_name = 1755851638.3859081_episode_339.json
#     数据集: actions -> 形状: (340, 7), 类型: float64
#     数据集: episode_step -> 形状: (340,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (340, 2), 类型: float32
#     数据集: is_success -> 形状: (340,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (340, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (340, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (340, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (340, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (340, 3), 类型: float32
#     数据集: rewards -> 形状: (340,), 类型: float64
#     数据集: robot_joint_states -> 形状: (340, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (340, 54), 类型: float32
#     数据集: socket_poses -> 形状: (340, 7), 类型: float32
#   组: demo_45
#     属性: demo_45.demo_name = 1755851684.5909412_episode_340.json
#     数据集: actions -> 形状: (341, 7), 类型: float64
#     数据集: episode_step -> 形状: (341,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (341, 2), 类型: float32
#     数据集: is_success -> 形状: (341,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (341, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (341, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (341, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (341, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (341, 3), 类型: float32
#     数据集: rewards -> 形状: (341,), 类型: float64
#     数据集: robot_joint_states -> 形状: (341, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (341, 54), 类型: float32
#     数据集: socket_poses -> 形状: (341, 7), 类型: float32
#   组: demo_46
#     属性: demo_46.demo_name = 1755851719.7491403_episode_255.json
#     数据集: actions -> 形状: (256, 7), 类型: float64
#     数据集: episode_step -> 形状: (256,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (256, 2), 类型: float32
#     数据集: is_success -> 形状: (256,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (256, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (256, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (256, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (256, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (256, 3), 类型: float32
#     数据集: rewards -> 形状: (256,), 类型: float64
#     数据集: robot_joint_states -> 形状: (256, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (256, 54), 类型: float32
#     数据集: socket_poses -> 形状: (256, 7), 类型: float32
#   组: demo_47
#     属性: demo_47.demo_name = 1755851759.9202697_episode_283.json
#     数据集: actions -> 形状: (284, 7), 类型: float64
#     数据集: episode_step -> 形状: (284,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (284, 2), 类型: float32
#     数据集: is_success -> 形状: (284,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (284, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (284, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (284, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (284, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (284, 3), 类型: float32
#     数据集: rewards -> 形状: (284,), 类型: float64
#     数据集: robot_joint_states -> 形状: (284, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (284, 54), 类型: float32
#     数据集: socket_poses -> 形状: (284, 7), 类型: float32
#   组: demo_48
#     属性: demo_48.demo_name = 1755851848.8412647_episode_260.json
#     数据集: actions -> 形状: (261, 7), 类型: float64
#     数据集: episode_step -> 形状: (261,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (261, 2), 类型: float32
#     数据集: is_success -> 形状: (261,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (261, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (261, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (261, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (261, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (261, 3), 类型: float32
#     数据集: rewards -> 形状: (261,), 类型: float64
#     数据集: robot_joint_states -> 形状: (261, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (261, 54), 类型: float32
#     数据集: socket_poses -> 形状: (261, 7), 类型: float32
#   组: demo_49
#     属性: demo_49.demo_name = 1755851937.442622_episode_322.json
#     数据集: actions -> 形状: (323, 7), 类型: float64
#     数据集: episode_step -> 形状: (323,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (323, 2), 类型: float32
#     数据集: is_success -> 形状: (323,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (323, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (323, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (323, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (323, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (323, 3), 类型: float32
#     数据集: rewards -> 形状: (323,), 类型: float64
#     数据集: robot_joint_states -> 形状: (323, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (323, 54), 类型: float32
#     数据集: socket_poses -> 形状: (323, 7), 类型: float32
#   组: demo_5
#     属性: demo_5.demo_name = 1755849219.5309644_episode_307.json
#     数据集: actions -> 形状: (308, 7), 类型: float64
#     数据集: episode_step -> 形状: (308,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (308, 2), 类型: float32
#     数据集: is_success -> 形状: (308,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (308, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (308, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (308, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (308, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (308, 3), 类型: float32
#     数据集: rewards -> 形状: (308,), 类型: float64
#     数据集: robot_joint_states -> 形状: (308, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (308, 54), 类型: float32
#     数据集: socket_poses -> 形状: (308, 7), 类型: float32
#   组: demo_50
#     属性: demo_50.demo_name = 1755851990.9418736_episode_377.json
#     数据集: actions -> 形状: (378, 7), 类型: float64
#     数据集: episode_step -> 形状: (378,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (378, 2), 类型: float32
#     数据集: is_success -> 形状: (378,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (378, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (378, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (378, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (378, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (378, 3), 类型: float32
#     数据集: rewards -> 形状: (378,), 类型: float64
#     数据集: robot_joint_states -> 形状: (378, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (378, 54), 类型: float32
#     数据集: socket_poses -> 形状: (378, 7), 类型: float32
#   组: demo_51
#     属性: demo_51.demo_name = 1755852033.1459491_episode_296.json
#     数据集: actions -> 形状: (297, 7), 类型: float64
#     数据集: episode_step -> 形状: (297,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (297, 2), 类型: float32
#     数据集: is_success -> 形状: (297,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (297, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (297, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (297, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (297, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (297, 3), 类型: float32
#     数据集: rewards -> 形状: (297,), 类型: float64
#     数据集: robot_joint_states -> 形状: (297, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (297, 54), 类型: float32
#     数据集: socket_poses -> 形状: (297, 7), 类型: float32
#   组: demo_52
#     属性: demo_52.demo_name = 1755852094.481561_episode_377.json
#     数据集: actions -> 形状: (378, 7), 类型: float64
#     数据集: episode_step -> 形状: (378,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (378, 2), 类型: float32
#     数据集: is_success -> 形状: (378,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (378, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (378, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (378, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (378, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (378, 3), 类型: float32
#     数据集: rewards -> 形状: (378,), 类型: float64
#     数据集: robot_joint_states -> 形状: (378, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (378, 54), 类型: float32
#     数据集: socket_poses -> 形状: (378, 7), 类型: float32
#   组: demo_53
#     属性: demo_53.demo_name = 1755852131.962825_episode_260.json
#     数据集: actions -> 形状: (261, 7), 类型: float64
#     数据集: episode_step -> 形状: (261,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (261, 2), 类型: float32
#     数据集: is_success -> 形状: (261,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (261, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (261, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (261, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (261, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (261, 3), 类型: float32
#     数据集: rewards -> 形状: (261,), 类型: float64
#     数据集: robot_joint_states -> 形状: (261, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (261, 54), 类型: float32
#     数据集: socket_poses -> 形状: (261, 7), 类型: float32
#   组: demo_54
#     属性: demo_54.demo_name = 1756716946.0592132_episode_228.json
#     数据集: actions -> 形状: (229, 7), 类型: float64
#     数据集: episode_step -> 形状: (229,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (229, 2), 类型: float32
#     数据集: is_success -> 形状: (229,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (229, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (229, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (229, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (229, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (229, 3), 类型: float32
#     数据集: rewards -> 形状: (229,), 类型: float64
#     数据集: robot_joint_states -> 形状: (229, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (229, 54), 类型: float32
#     数据集: socket_poses -> 形状: (229, 7), 类型: float32
#   组: demo_55
#     属性: demo_55.demo_name = 1756717110.0571764_episode_257.json
#     数据集: actions -> 形状: (258, 7), 类型: float64
#     数据集: episode_step -> 形状: (258,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (258, 2), 类型: float32
#     数据集: is_success -> 形状: (258,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (258, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (258, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (258, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (258, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (258, 3), 类型: float32
#     数据集: rewards -> 形状: (258,), 类型: float64
#     数据集: robot_joint_states -> 形状: (258, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (258, 54), 类型: float32
#     数据集: socket_poses -> 形状: (258, 7), 类型: float32
#   组: demo_56
#     属性: demo_56.demo_name = 1756730884.7050316_episode_215.json
#     数据集: actions -> 形状: (216, 7), 类型: float64
#     数据集: episode_step -> 形状: (216,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (216, 2), 类型: float32
#     数据集: is_success -> 形状: (216,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (216, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (216, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (216, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (216, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (216, 3), 类型: float32
#     数据集: rewards -> 形状: (216,), 类型: float64
#     数据集: robot_joint_states -> 形状: (216, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (216, 54), 类型: float32
#     数据集: socket_poses -> 形状: (216, 7), 类型: float32
#   组: demo_57
#     属性: demo_57.demo_name = 1756717147.0673282_episode_247.json
#     数据集: actions -> 形状: (248, 7), 类型: float64
#     数据集: episode_step -> 形状: (248,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (248, 2), 类型: float32
#     数据集: is_success -> 形状: (248,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (248, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (248, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (248, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (248, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (248, 3), 类型: float32
#     数据集: rewards -> 形状: (248,), 类型: float64
#     数据集: robot_joint_states -> 形状: (248, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (248, 54), 类型: float32
#     数据集: socket_poses -> 形状: (248, 7), 类型: float32
#   组: demo_58
#     属性: demo_58.demo_name = 1756717194.202934_episode_251.json
#     数据集: actions -> 形状: (252, 7), 类型: float64
#     数据集: episode_step -> 形状: (252,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (252, 2), 类型: float32
#     数据集: is_success -> 形状: (252,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (252, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (252, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (252, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (252, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (252, 3), 类型: float32
#     数据集: rewards -> 形状: (252,), 类型: float64
#     数据集: robot_joint_states -> 形状: (252, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (252, 54), 类型: float32
#     数据集: socket_poses -> 形状: (252, 7), 类型: float32
#   组: demo_59
#     属性: demo_59.demo_name = 1756717266.237108_episode_228.json
#     数据集: actions -> 形状: (229, 7), 类型: float64
#     数据集: episode_step -> 形状: (229,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (229, 2), 类型: float32
#     数据集: is_success -> 形状: (229,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (229, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (229, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (229, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (229, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (229, 3), 类型: float32
#     数据集: rewards -> 形状: (229,), 类型: float64
#     数据集: robot_joint_states -> 形状: (229, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (229, 54), 类型: float32
#     数据集: socket_poses -> 形状: (229, 7), 类型: float32
#   组: demo_6
#     属性: demo_6.demo_name = 1755849260.178932_episode_266.json
#     数据集: actions -> 形状: (267, 7), 类型: float64
#     数据集: episode_step -> 形状: (267,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (267, 2), 类型: float32
#     数据集: is_success -> 形状: (267,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (267, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (267, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (267, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (267, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (267, 3), 类型: float32
#     数据集: rewards -> 形状: (267,), 类型: float64
#     数据集: robot_joint_states -> 形状: (267, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (267, 54), 类型: float32
#     数据集: socket_poses -> 形状: (267, 7), 类型: float32
#   组: demo_60
#     属性: demo_60.demo_name = 1756717302.0602992_episode_220.json
#     数据集: actions -> 形状: (221, 7), 类型: float64
#     数据集: episode_step -> 形状: (221,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (221, 2), 类型: float32
#     数据集: is_success -> 形状: (221,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (221, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (221, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (221, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (221, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (221, 3), 类型: float32
#     数据集: rewards -> 形状: (221,), 类型: float64
#     数据集: robot_joint_states -> 形状: (221, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (221, 54), 类型: float32
#     数据集: socket_poses -> 形状: (221, 7), 类型: float32
#   组: demo_61
#     属性: demo_61.demo_name = 1756717428.9640002_episode_533.json
#     数据集: actions -> 形状: (534, 7), 类型: float64
#     数据集: episode_step -> 形状: (534,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (534, 2), 类型: float32
#     数据集: is_success -> 形状: (534,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (534, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (534, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (534, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (534, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (534, 3), 类型: float32
#     数据集: rewards -> 形状: (534,), 类型: float64
#     数据集: robot_joint_states -> 形状: (534, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (534, 54), 类型: float32
#     数据集: socket_poses -> 形状: (534, 7), 类型: float32
#   组: demo_62
#     属性: demo_62.demo_name = 1756730767.4609385_episode_212.json
#     数据集: actions -> 形状: (213, 7), 类型: float64
#     数据集: episode_step -> 形状: (213,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (213, 2), 类型: float32
#     数据集: is_success -> 形状: (213,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (213, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (213, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (213, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (213, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (213, 3), 类型: float32
#     数据集: rewards -> 形状: (213,), 类型: float64
#     数据集: robot_joint_states -> 形状: (213, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (213, 54), 类型: float32
#     数据集: socket_poses -> 形状: (213, 7), 类型: float32
#   组: demo_63
#     属性: demo_63.demo_name = 1756730815.900072_episode_368.json
# ...
#     数据集: robot_measured_joint_forces -> 形状: (233, 54), 类型: float32
#     数据集: socket_poses -> 形状: (233, 7), 类型: float32
#   组: demo_65
#     属性: demo_65.demo_name = 1756818990.0073738_episode_328.json
#     数据集: actions -> 形状: (329, 7), 类型: float64
#     数据集: episode_step -> 形状: (329,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (329, 2), 类型: float32
#     数据集: is_success -> 形状: (329,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (329, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (329, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (329, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (329, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (329, 3), 类型: float32
#     数据集: rewards -> 形状: (329,), 类型: float64
#     数据集: robot_joint_states -> 形状: (329, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (329, 54), 类型: float32
#     数据集: socket_poses -> 形状: (329, 7), 类型: float32
#   组: demo_66
#     属性: demo_66.demo_name = 1756819002.5732567_episode_54.json
#     数据集: actions -> 形状: (55, 7), 类型: float64
#     数据集: episode_step -> 形状: (55,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (55, 2), 类型: float32
#     数据集: is_success -> 形状: (55,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (55, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (55, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (55, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (55, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (55, 3), 类型: float32
#     数据集: rewards -> 形状: (55,), 类型: float64
#     数据集: robot_joint_states -> 形状: (55, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (55, 54), 类型: float32
#     数据集: socket_poses -> 形状: (55, 7), 类型: float32
#   组: demo_67
#     属性: demo_67.demo_name = 1756819470.117595_episode_301.json
#     数据集: actions -> 形状: (302, 7), 类型: float64
#     数据集: episode_step -> 形状: (302,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (302, 2), 类型: float32
#     数据集: is_success -> 形状: (302,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (302, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (302, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (302, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (302, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (302, 3), 类型: float32
#     数据集: rewards -> 形状: (302,), 类型: float64
#     数据集: robot_joint_states -> 形状: (302, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (302, 54), 类型: float32
#     数据集: socket_poses -> 形状: (302, 7), 类型: float32
#   组: demo_68
#     属性: demo_68.demo_name = 1756819521.2875998_episode_282.json
#     数据集: actions -> 形状: (283, 7), 类型: float64
#     数据集: episode_step -> 形状: (283,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (283, 2), 类型: float32
#     数据集: is_success -> 形状: (283,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (283, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (283, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (283, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (283, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (283, 3), 类型: float32
#     数据集: rewards -> 形状: (283,), 类型: float64
#     数据集: robot_joint_states -> 形状: (283, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (283, 54), 类型: float32
#     数据集: socket_poses -> 形状: (283, 7), 类型: float32
#   组: demo_69
#     属性: demo_69.demo_name = 1756819558.1135907_episode_267.json
#     数据集: actions -> 形状: (268, 7), 类型: float64
#     数据集: episode_step -> 形状: (268,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (268, 2), 类型: float32
#     数据集: is_success -> 形状: (268,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (268, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (268, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (268, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (268, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (268, 3), 类型: float32
#     数据集: rewards -> 形状: (268,), 类型: float64
#     数据集: robot_joint_states -> 形状: (268, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (268, 54), 类型: float32
#     数据集: socket_poses -> 形状: (268, 7), 类型: float32
#   组: demo_7
#     属性: demo_7.demo_name = 1755849297.7026813_episode_270.json
#     数据集: actions -> 形状: (271, 7), 类型: float64
#     数据集: episode_step -> 形状: (271,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (271, 2), 类型: float32
#     数据集: is_success -> 形状: (271,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (271, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (271, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (271, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (271, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (271, 3), 类型: float32
#     数据集: rewards -> 形状: (271,), 类型: float64
#     数据集: robot_joint_states -> 形状: (271, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (271, 54), 类型: float32
#     数据集: socket_poses -> 形状: (271, 7), 类型: float32
#   组: demo_70
#     属性: demo_70.demo_name = 1756819629.6712253_episode_289.json
#     数据集: actions -> 形状: (290, 7), 类型: float64
#     数据集: episode_step -> 形状: (290,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (290, 2), 类型: float32
#     数据集: is_success -> 形状: (290,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (290, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (290, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (290, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (290, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (290, 3), 类型: float32
#     数据集: rewards -> 形状: (290,), 类型: float64
#     数据集: robot_joint_states -> 形状: (290, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (290, 54), 类型: float32
#     数据集: socket_poses -> 形状: (290, 7), 类型: float32
#   组: demo_71
#     属性: demo_71.demo_name = 1756819662.314575_episode_207.json
#     数据集: actions -> 形状: (208, 7), 类型: float64
#     数据集: episode_step -> 形状: (208,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (208, 2), 类型: float32
#     数据集: is_success -> 形状: (208,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (208, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (208, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (208, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (208, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (208, 3), 类型: float32
#     数据集: rewards -> 形状: (208,), 类型: float64
#     数据集: robot_joint_states -> 形状: (208, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (208, 54), 类型: float32
#     数据集: socket_poses -> 形状: (208, 7), 类型: float32
#   组: demo_72
#     属性: demo_72.demo_name = 1756819696.7450027_episode_244.json
#     数据集: actions -> 形状: (245, 7), 类型: float64
#     数据集: episode_step -> 形状: (245,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (245, 2), 类型: float32
#     数据集: is_success -> 形状: (245,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (245, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (245, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (245, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (245, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (245, 3), 类型: float32
#     数据集: rewards -> 形状: (245,), 类型: float64
#     数据集: robot_joint_states -> 形状: (245, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (245, 54), 类型: float32
#     数据集: socket_poses -> 形状: (245, 7), 类型: float32
#   组: demo_73
#     属性: demo_73.demo_name = 1756819739.8639529_episode_251.json
#     数据集: actions -> 形状: (252, 7), 类型: float64
#     数据集: episode_step -> 形状: (252,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (252, 2), 类型: float32
#     数据集: is_success -> 形状: (252,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (252, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (252, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (252, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (252, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (252, 3), 类型: float32
#     数据集: rewards -> 形状: (252,), 类型: float64
#     数据集: robot_joint_states -> 形状: (252, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (252, 54), 类型: float32
#     数据集: socket_poses -> 形状: (252, 7), 类型: float32
#   组: demo_74
#     属性: demo_74.demo_name = 1756819039.5040236_episode_184.json
#     数据集: actions -> 形状: (185, 7), 类型: float64
#     数据集: episode_step -> 形状: (185,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (185, 2), 类型: float32
#     数据集: is_success -> 形状: (185,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (185, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (185, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (185, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (185, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (185, 3), 类型: float32
#     数据集: rewards -> 形状: (185,), 类型: float64
#     数据集: robot_joint_states -> 形状: (185, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (185, 54), 类型: float32
#     数据集: socket_poses -> 形状: (185, 7), 类型: float32
#   组: demo_75
#     属性: demo_75.demo_name = 1756819070.464976_episode_166.json
#     数据集: actions -> 形状: (167, 7), 类型: float64
#     数据集: episode_step -> 形状: (167,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (167, 2), 类型: float32
#     数据集: is_success -> 形状: (167,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (167, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (167, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (167, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (167, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (167, 3), 类型: float32
#     数据集: rewards -> 形状: (167,), 类型: float64
#     数据集: robot_joint_states -> 形状: (167, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (167, 54), 类型: float32
#     数据集: socket_poses -> 形状: (167, 7), 类型: float32
#   组: demo_76
#     属性: demo_76.demo_name = 1756819198.4700992_episode_259.json
#     数据集: actions -> 形状: (260, 7), 类型: float64
#     数据集: episode_step -> 形状: (260,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (260, 2), 类型: float32
#     数据集: is_success -> 形状: (260,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (260, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (260, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (260, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (260, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (260, 3), 类型: float32
#     数据集: rewards -> 形状: (260,), 类型: float64
#     数据集: robot_joint_states -> 形状: (260, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (260, 54), 类型: float32
#     数据集: socket_poses -> 形状: (260, 7), 类型: float32
#   组: demo_77
#     属性: demo_77.demo_name = 1756819243.0051224_episode_225.json
#     数据集: actions -> 形状: (226, 7), 类型: float64
#     数据集: episode_step -> 形状: (226,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (226, 2), 类型: float32
#     数据集: is_success -> 形状: (226,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (226, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (226, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (226, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (226, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (226, 3), 类型: float32
#     数据集: rewards -> 形状: (226,), 类型: float64
#     数据集: robot_joint_states -> 形状: (226, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (226, 54), 类型: float32
#     数据集: socket_poses -> 形状: (226, 7), 类型: float32
#   组: demo_78
#     属性: demo_78.demo_name = 1756819309.3372731_episode_502.json
#     数据集: actions -> 形状: (503, 7), 类型: float64
#     数据集: episode_step -> 形状: (503,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (503, 2), 类型: float32
#     数据集: is_success -> 形状: (503,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (503, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (503, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (503, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (503, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (503, 3), 类型: float32
#     数据集: rewards -> 形状: (503,), 类型: float64
#     数据集: robot_joint_states -> 形状: (503, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (503, 54), 类型: float32
#     数据集: socket_poses -> 形状: (503, 7), 类型: float32
#   组: demo_79
#     属性: demo_79.demo_name = 1756819358.128671_episode_301.json
#     数据集: actions -> 形状: (302, 7), 类型: float64
#     数据集: episode_step -> 形状: (302,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (302, 2), 类型: float32
#     数据集: is_success -> 形状: (302,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (302, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (302, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (302, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (302, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (302, 3), 类型: float32
#     数据集: rewards -> 形状: (302,), 类型: float64
#     数据集: robot_joint_states -> 形状: (302, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (302, 54), 类型: float32
#     数据集: socket_poses -> 形状: (302, 7), 类型: float32
#   组: demo_8
#     属性: demo_8.demo_name = 1755849357.8054104_episode_354.json
#     数据集: actions -> 形状: (355, 7), 类型: float64
#     数据集: episode_step -> 形状: (355,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (355, 2), 类型: float32
#     数据集: is_success -> 形状: (355,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (355, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (355, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (355, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (355, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (355, 3), 类型: float32
#     数据集: rewards -> 形状: (355,), 类型: float64
#     数据集: robot_joint_states -> 形状: (355, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (355, 54), 类型: float32
#     数据集: socket_poses -> 形状: (355, 7), 类型: float32
#   组: demo_80
#     属性: demo_80.demo_name = 1756819402.1367083_episode_303.json
#     数据集: actions -> 形状: (304, 7), 类型: float64
#     数据集: episode_step -> 形状: (304,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (304, 2), 类型: float32
#     数据集: is_success -> 形状: (304,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (304, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (304, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (304, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (304, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (304, 3), 类型: float32
#     数据集: rewards -> 形状: (304,), 类型: float64
#     数据集: robot_joint_states -> 形状: (304, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (304, 54), 类型: float32
#     数据集: socket_poses -> 形状: (304, 7), 类型: float32
#   组: demo_81
#     属性: demo_81.demo_name = 1756819431.5345807_episode_224.json
#     数据集: actions -> 形状: (225, 7), 类型: float64
#     数据集: episode_step -> 形状: (225,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (225, 2), 类型: float32
#     数据集: is_success -> 形状: (225,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (225, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (225, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (225, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (225, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (225, 3), 类型: float32
#     数据集: rewards -> 形状: (225,), 类型: float64
#     数据集: robot_joint_states -> 形状: (225, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (225, 54), 类型: float32
#     数据集: socket_poses -> 形状: (225, 7), 类型: float32
#   组: demo_9
#     属性: demo_9.demo_name = 1755849395.5384696_episode_264.json
#     数据集: actions -> 形状: (265, 7), 类型: float64
#     数据集: episode_step -> 形状: (265,), 类型: int64
#     数据集: gripper_joint_states -> 形状: (265, 2), 类型: float32
#     数据集: is_success -> 形状: (265,), 类型: bool
#     组: observations
#       数据集: agentview_rgb -> 形状: (265, 128, 128, 3), 类型: uint8
#       数据集: ee_poses -> 形状: (265, 7), 类型: float64
#       数据集: hand_camera_rgb -> 形状: (265, 128, 128, 3), 类型: uint8
#     数据集: plug_poses -> 形状: (265, 7), 类型: float32
#     数据集: plug_socket_forces -> 形状: (265, 3), 类型: float32
#     数据集: rewards -> 形状: (265,), 类型: float64
#     数据集: robot_joint_states -> 形状: (265, 14), 类型: float32
#     数据集: robot_measured_joint_forces -> 形状: (265, 54), 类型: float32
#     数据集: socket_poses -> 形状: (265, 7), 类型: float32

# %%
# check what is in one npz file
import numpy as np

# 加载 .npz 文件
file_path = '/home/wdy02/software/isaacsim/wdy_data/bc_data/npz/ONE_PEG_IN_HOLE_60/demo_0.npz'  # 替换为你的 .npz 文件路径
data = np.load(file_path)

# 查看文件中包含哪些数组（键）
print("文件中的数组名称（键）:")
print(data.files)

# 遍历每个数组，查看其形状、数据类型和大小
print("\n数组详细信息:")
for key in data.files:
    array = data[key]
    print(f"键名: {key}")
    print(f"  形状 (shape): {array.shape}")
    print(f"  数据类型 (dtype): {array.dtype}")
    print(f"  大小 (元素个数): {array.size}")
    print(f"  占用内存 (近似字节数): {array.nbytes} 字节")
    print("-" * 40)

# 关闭文件
data.close()
# Out:
# 文件中的数组名称（键）:
# ['front_rgb', 'wrist_rgb', 'ee_pose', 'joint_forces', 'contact_forces', 'joint_states', 'action']
#
# 数组详细信息:
# 键名: front_rgb
#   形状 (shape): (195, 128, 128, 3)
#   数据类型 (dtype): uint8
#   大小 (元素个数): 9584640
#   占用内存 (近似字节数): 9584640 字节
# ----------------------------------------
# 键名: wrist_rgb
#   形状 (shape): (195, 128, 128, 3)
#   数据类型 (dtype): uint8
#   大小 (元素个数): 9584640
#   占用内存 (近似字节数): 9584640 字节
# ----------------------------------------
# 键名: ee_pose
#   形状 (shape): (195, 7)
#   数据类型 (dtype): float32
#   大小 (元素个数): 1365
#   占用内存 (近似字节数): 5460 字节
# ----------------------------------------
# 键名: joint_forces
#   形状 (shape): (195, 54)
#   数据类型 (dtype): float32
#   大小 (元素个数): 10530
#   占用内存 (近似字节数): 42120 字节
# ----------------------------------------
# 键名: contact_forces
#   形状 (shape): (195, 3)
#   数据类型 (dtype): float32
#   大小 (元素个数): 585
#   占用内存 (近似字节数): 2340 字节
# ----------------------------------------
# 键名: joint_states
#   形状 (shape): (195, 14)
#   数据类型 (dtype): float32
#   大小 (元素个数): 2730
#   占用内存 (近似字节数): 10920 字节
# ----------------------------------------
# 键名: action
#   形状 (shape): (195, 7)
#   数据类型 (dtype): float32
#   大小 (元素个数): 1365
#   占用内存 (近似字节数): 5460 字节
# ----------------------------------------
